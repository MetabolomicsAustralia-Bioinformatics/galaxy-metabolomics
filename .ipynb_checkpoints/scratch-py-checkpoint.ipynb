# %%
import numpy as np
import pandas as pd

# %%
d0 = pd.read_csv("~/Documents/galaxy-metabolomics/data-test/fake_data.csv")

# %%
d0
# Out:
#    sample      group  N-Acetylglutamine  Coenzyme A  Aminoadipic acid  \
# 0      s1  treatment            1367588     4026575              3817
# 1      s2  treatment            1756666     3182616             13754
# 2      s3  treatment            1961779     2639077             24914
# 3      s4  treatment            1601174     3080883              2168
# 4      s5  treatment            1839876     2159348              6521
# 5      s6  treatment            1648465     2660196              7496
# 6      s7    control            1593415      648981             23196
# 7      s8    control            2073077      571445              9830
# 8      s9    control             975662     1683377             14920
# 9     s10    control            1356760      803558             23065
# 10    s11    control             863489     2585497              6742
# 11    s12    control             767455     3072688             19150
#
# ...
